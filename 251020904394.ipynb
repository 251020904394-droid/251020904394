# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904394-droid/251020904394/blob/main/251020904394.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Nhap so nguyen duong n: ",))
o=0
for i in range (n+1):
  if i%2==0:
    o+=i
print(o)
# Out:
# Nhap so nguyen duong n: 10
# 30

# %%
n = input("Nhập chuỗi: ")
tungtu = n.split()
maxtu = ""
for tu in tungtu:
    if len(tu) > len(maxtu):
        maxtu = tu
print(len(maxtu), "tu dai nhat:", maxtu)
# Out:
# Nhập chuỗi: lap trinh python co ban
# 6 tu dai nhat: python

# %%
songuyen = list(map(int, input("Nhap cac so nguyen: ").split()))
songuyen = list(set(songuyen))
songuyen.sort()
print("Danh sách sau khi xử lý:", songuyen)
if len(songuyen) < 2:
    print("Không tồn tại số lớn thứ hai")
else:
    print("Số lớn thứ hai là:", songuyen[-2])
# Out:
# Nhap cac so nguyen: 5 1 3 5 2 3
# Danh sách sau khi xử lý: [1, 2, 3, 5]
# Số lớn thứ hai là: 3

# %%
n=input(" ",)
nn=n.split()
tungdiem=list(map(int,nn))
diemtong=0
quamon=0
for i in tungdiem:
  if i>=5 and i<10:
    quamon+=1
    diemtong+=i
diemtrungbinh=diemtong/quamon
print("Diem trung binh: ",diemtrungbinh ,"Qua mon: ",quamon)
# Out:
#  7 8 11 -1 4 5
# Diem trung binh:  6.666666666666667 Qua mon:  3
